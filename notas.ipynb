# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/jonathanbff/rascunhos/main/StudentsPerformance.csv?token=AQPCC2UFCHGYLVQP4HT42I3AJUL3C")
dataset.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
dataset.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
dataset.dropna()
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]

# %%
sns.lmplot(data=dataset, x="writing score", y="math score", col="gender", hue="race/ethnicity")

# %%
dataset.plot.scatter('gender','math score')

# %%
dataset.plot.box('math score','gender')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-56e947c57e0a> in <module>()
# ----> 1 dataset.plot.box('math score','gender')
#
# TypeError: box() takes from 1 to 2 positional arguments but 3 were given

# %%
dataset['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
dataset.hist(column='math score');

# %%
dataset.plot.box()

# %%
femininas.np = (i == 'female' for i in dataset['gender'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-cef77dd15695> in <module>()
# ----> 1 femininas.np = (i == 'female' for i in dataset['gender'])
#
# AttributeError: 'generator' object has no attribute 'np'

# %%
print(femininas)
# Out:
# <generator object <genexpr> at 0x7f78379e78d0>
